# %% [markdown]
# # Análisis Final de Resultados
#
# ## Comparativa de Modelos
# El modelo integrado (Random Forest + Clusters) demostró ser superior.
#
# | Modelo | Accuracy | Estado |
# | :--- | :--- | :--- |
# | Baseline (LogReg) | 30.8% | Insuficiente |
# | **Integrado (RF + K-Means)** | **83.4%** | **Exitoso** |
#
# ## Conclusión
# La orquestación con Airflow funcionó correctamente, ejecutando el flujo completo en ~15 segundos.
